# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
dic = {'mayank':[1,2,3,4,5]}

# %%
df = pd.DataFrame(dic)

# %%
df.set_index(["mayank"])
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 2, 3, 4, 5]

# %%
print("tupls")
# Out:
# tupls

# %%
s={'hero': 7.84,'mayank': 8.24, 'ashwin': 8.78}
naam = list(s.keys())
hmm = list(s.values())

# %%
HH = pd.DataFrame(s,columns=['name','int'])

# %% [raw]
# print(HH)

# %%
print(HH)
# Out:
# Empty DataFrame
# Columns: [name, int]
# Index: []

# %%
plt.xlabel("naam")
plt.ylabel("hmm")

plt.bar(naam , hmm ,color = "skyblue")
# Out:
# <BarContainer object of 3 artists>

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.__version__
# Out:
# '3.8.4'

# %%
movies = {
    'TV Show': ['Breaking Bad', 'Stranger Things', 'Game of Thrones', 'The Mandalorian', 'The Crown'],
    'IMDb Rating': [9.5, 8.7, 9.3, 8.8, 8.7],
    'Social Media Mentions': [1200000, 1500000, 1800000, 2000000, 1100000],
    'Total Views (millions)': [50, 60, 80, 70, 40],
    'Awards Won': [100, 50, 80, 60, 40],
    'Critic Rating (Metacritic)': [92, 85, 91, 82, 88],
    'Viewer Sentiment (%)': [95, 89, 94, 90, 88]
}

# %%
movies[['IMDb Rating', 'Social Media Mentions', 'Total Views (millions)', 'Awards Won', 'Critic Rating (Metacritic)', 'Viewer Sentiment (%)']].hist(bins=5, figsize=(8,9))
# Out:
# array([[<Axes: title={'center': 'IMDb Rating'}>,
#         <Axes: title={'center': 'Social Media Mentions'}>],
#        [<Axes: title={'center': 'Total Views (millions)'}>,
#         <Axes: title={'center': 'Awards Won'}>],
#        [<Axes: title={'center': 'Critic Rating (Metacritic)'}>,
#         <Axes: title={'center': 'Viewer Sentiment (%)'}>]], dtype=object)

# %%
import numpy as np;
BLOCKCHAINMARKS = [88,85,83,82,82,81,81,81,80,80,79,79,79,79,79,79,79,78,78,77,77,77,77,76,76,75,75,75,74,74,74,74,74,74,73,73,73,73,72,72,72,71,71,69,69,69,69,69,68,68,68,68,68,67,67,67,67,67,66,66,65,65,65,64,64,64,64,64,64,64,63,63,63,63,63,63,62,62,62,62,62,61,61,61,61,61,60,59,58,58,58,58,58,58]

plt.hist(BLOCKCHAINMARKS , bins=18, edgecolor='RED', color="green", width = 2,
         alpha=0.7)
bin_counts, bin_edges = np.histogram(BLOCKCHAINMARKS , bins=15)
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_midpoints, bin_counts,  color='orange', linestyle='solid', label='Frequency Polygon')
plt.title('Frequency Polygon of marks')
plt.xlabel('MARKS')
plt.ylabel('Frequency')

plt.tight_layout() 
plt.show()

# %%
import numpy as np;
BLOCKCHAINMARKS = [88,85,83,82,82,81,81,81,80,80,79,79,79,79,79,79,79,78,78,77,77,77,77,76,76,75,75,75,74,74,74,74,74,74,73,73,73,73,72,72,72,71,71,69,69,69,69,69,68,68,68,68,68,67,67,67,67,67,66,66,65,65,65,64,64,64,64,64,64,64,63,63,63,63,63,63,62,62,62,62,62,61,61,61,61,61,60,59,58,58,58,58,58,58]

plt.hist(BLOCKCHAINMARKS , bins=18, edgecolor='RED', color="green", width = 2,
         alpha=0.7)
bin_counts, bin_edges = np.histogram(BLOCKCHAINMARKS , bins=15)
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_midpoints, bin_counts,  color='orange', linestyle='solid', label='Frequency Polygon')
plt.title('Frequency Polygon of marks')
plt.xlabel('MARKS')
plt.ylabel('Frequency')

plt.tight_layout() 
plt.show()

# %%
import numpy as np;
BLOCKCHAINMARKS = [88,85,83,82,82,81,81,81,80,80,79,79,79,79,79,79,79,78,78,77,77,77,77,76,76,75,75,75,74,74,74,74,74,74,73,73,73,73,72,72,72,71,71,69,69,69,69,69,68,68,68,68,68,67,67,67,67,67,66,66,65,65,65,64,64,64,64,64,64,64,63,63,63,63,63,63,62,62,62,62,62,61,61,61,61,61,60,59,58,58,58,58,58,58]

plt.hist(BLOCKCHAINMARKS , bins=18, edgecolor='RED', color="green", width = 2,
         alpha=0.7)
bin_counts, bin_edges = np.histogram(BLOCKCHAINMARKS , bins=15)
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_midpoints, bin_counts,  color='orange', linestyle='solid', label='Frequency Polygon')
plt.title('Frequency Polygon of marks')
plt.xlabel('MARKS')
plt.ylabel('Frequency')

plt.tight_layout() 
plt.show()

# %%
import numpy as np;
BLOCKCHAINMARKS = [88,85,83,82,82,81,81,81,80,80,79,79,79,79,79,79,79,78,78,77,77,77,77,76,76,75,75,75,74,74,74,74,74,74,73,73,73,73,72,72,72,71,71,69,69,69,69,69,68,68,68,68,68,67,67,67,67,67,66,66,65,65,65,64,64,64,64,64,64,64,63,63,63,63,63,63,62,62,62,62,62,61,61,61,61,61,60,59,58,58,58,58,58,58]

plt.hist(BLOCKCHAINMARKS , bins=18, edgecolor='RED', color="green", width = 2,
         alpha=0.7)
bin_counts, bin_edges = np.histogram(BLOCKCHAINMARKS , bins=15)
bin_midpoints = (bin_edges[:-1] + bin_edges[1:]) / 2
plt.plot(bin_midpoints, bin_counts,  color='orange', linestyle='solid', label='Frequency Polygon')
plt.title('Frequency Polygon of marks')
plt.xlabel('MARKS')
plt.ylabel('Frequency')

plt.tight_layout() 
plt.show()
