# %%
data = {'A': np.random.randint(1, 300, 30), 
        'B': np.random.randint(1, 300, 30), 
        'C': np.random.randint(1, 300, 30), 
        'D': np.random.randint(1, 300, 30)}
df = pd.DataFrame(data)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

print("\n### Experiment 5: Averages ###")
print("Mean:", np.mean(df['A']))
print("Median:", np.median(df['A']))
print("Mode:", stats.mode(df['A'], keepdims=True).mode.item())
print("Column-wise Mean:\n", df.mean())
print("Column-wise Median:\n", df.median())
print("Column-wise Mode:\n", df.mode())

print("\n### Experiment 6: Variability ###")
print("Standard Deviation:", np.std(df['A']))
print("Variance:", np.var(df['A']))
print("Range:", np.max(df['A']) - np.min(df['A']))
print("Column-wise Variance:\n", df.var())
print("Column-wise Standard Deviation:\n", df.std())
print("Summary Statistics:\n", df.describe().loc[['std']])

print("\n### Experiment 7: Normal Curves ###")
x = np.linspace(-5, 5, 300)
y = stats.norm.pdf(x, 0, 1)
plt.plot(x, y, color='g', label='Standard Normal Curve')
y2 = stats.norm.pdf(x, 1, 2)
plt.plot(x, y2, color='r', linestyle='dashed', label='Mean=1, Std=2')
plt.title('Normal Distribution Curves')
plt.legend()
plt.show()

print("\n### Experiment 8: Correlation and Scatter Plots ###")
plt.figure(figsize=(10,6))
plt.scatter(df['A'], df['B'], c=df['C'], cmap='coolwarm', alpha=0.7)
plt.colorbar(label='C values')
plt.xlabel('A')
plt.ylabel('B')
plt.title('Scatter Plot between A and B')
plt.show()

print("\n### Experiment 9: Correlation Coefficient ###")
corr_matrix = df.corr()
print("Correlation Matrix:\n", corr_matrix)
print("Correlation between A and B:", df['A'].corr(df['B']))
plt.figure(figsize=(8,6))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr_matrix)), corr_matrix.columns, rotation=45)
plt.yticks(range(len(corr_matrix)), corr_matrix.columns)
plt.title('Correlation Matrix Heatmap')
plt.show()

print("\n### Experiment 10: Regression ###")
slope, intercept, r_value, p_value, std_err = stats.linregress(df['A'], df['B'])
print(f"Regression Equation: Y = {slope:.2f}X + {intercept:.2f}")
print("R-squared Value:", r_value**2)
print("P-value:", p_value)
plt.figure(figsize=(10,6))
plt.scatter(df['A'], df['B'], label='Data Points')
plt.plot(df['A'], slope*df['A'] + intercept, color='r', label='Regression Line')
plt.xlabel('A')
plt.ylabel('B')
plt.title('Linear Regression')
plt.legend()
plt.show()
# Out:
# ### Experiment 5: Averages ###
# Mean: 166.13333333333333
# Median: 166.0
# Mode: 17
# Column-wise Mean:
#  A    166.133333
# B    143.733333
# C    168.166667
# D    158.033333
# dtype: float64
# Column-wise Median:
#  A    166.0
# B    151.0
# C    187.5
# D    160.5
# dtype: float64
# Column-wise Mode:
#        A      B    C    D
# 0    17  199.0    3   22
# 1    54  226.0   25   31
# 2    56    NaN   26   33
# 3    76    NaN   34   41
# 4    89    NaN   43   68
# 5    99    NaN   62   78
# 6   103    NaN   94   81
# 7   110    NaN   97   82
# 8   121    NaN  108  103
# 9   127    NaN  117  117
# 10  135    NaN  138  131
# 11  138    NaN  144  135
# 12  149    NaN  158  151
# 13  159    NaN  165  152
# 14  163    NaN  181  160
# 15  169    NaN  194  161
# 16  170    NaN  196  165
# 17  177    NaN  219  172
# 18  178    NaN  222  176
# 19  183    NaN  225  192
# 20  226    NaN  228  212
# 21  230    NaN  230  214
# 22  240    NaN  244  229
# 23  241    NaN  246  243
# 24  247    NaN  266  244
# 25  251    NaN  269  251
# 26  258    NaN  271  261
# 27  265    NaN  276  262
# 28  267    NaN  278  276
# 29  286    NaN  286  298
#
# ### Experiment 6: Variability ###
# Standard Deviation: 71.67832463319871
# Variance: 5137.782222222221
# Range: 269
# Column-wise Variance:
#  A    5314.947126
# B    9640.754023
# C    7888.212644
# D    6456.654023
# dtype: float64
# Column-wise Standard Deviation:
#  A    72.903684
# B    98.187341
# C    88.815610
# D    80.353307
# dtype: float64
# Summary Statistics:
#               A          B         C          D
# std  72.903684  98.187341  88.81561  80.353307
#
# ### Experiment 7: Normal Curves ###
# ### Experiment 8: Correlation and Scatter Plots ###
# ### Experiment 9: Correlation Coefficient ###
# Correlation Matrix:
#            A         B         C         D
# A  1.000000 -0.025613 -0.088157  0.186197
# B -0.025613  1.000000  0.364443  0.012121
# C -0.088157  0.364443  1.000000  0.047336
# D  0.186197  0.012121  0.047336  1.000000
# Correlation between A and B: -0.02561286978928221
# ### Experiment 10: Regression ###
# Regression Equation: Y = -0.03X + 149.46
# R-squared Value: 0.0006560190988427252
# P-value: 0.8931272257843457
